# %% [markdown]
# # Analyzing Historical Stock/Revenue Data

# %% [markdown]
# ## Author
# Omar Patricio Juárez Álvarez

# %% [markdown]
# ### Question 1

# %% [markdown]
# ![tsla_stock.png](attachment:cc9a4d66-b960-44b3-a031-7bb87d236018.png)

# %% [markdown]
# ### Question 2

# %% [markdown]
# ![tsla_rev.png](attachment:19fd336e-03bb-4a39-98a8-b3a1da59e207.png)

# %% [markdown]
# ### Question 3

# %% [markdown]
# ### Question 4

# %% [markdown]
# ### Question 5

# %% [markdown]
# ### Question 6
